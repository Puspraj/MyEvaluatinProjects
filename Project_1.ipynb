# %%
# !pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd
import numpy as np

# %%
con=mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password='Aa7903176169@',
    database="student")

# %%
student=pd.read_sql_query('select * from student_marks',con)
student.head()
# Out:
#        name gender         dob  math  physics  chemistry  english  biology  \
# 0      John      M  05-04-1988    55       45         56       87       21
# 1    Suresh      M  04-05-1987    75       96         78       64       90
# 2    Ramesh      M  25-05-1989    25       54         89       76       95
# 3   Jessica      F  12-08-1990    78       96         86       63       54
# 4  Jennifer      F  02-09-1989    58       96         78       46       96
#
#    economics  history  civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
df=pd.DataFrame(data=student)
df.tail()
# Out:
#      name gender         dob  math  physics  chemistry  english  biology  \
# 5    Annu      F  05-04-1988    45       87         52       89       55
# 6   pooja      F  04-05-1987    55       64         61       58       75
# 7  Ritesh      M  25-05-1989    54       76         87       56       25
# 8   Farha      F  12-08-1990    55       63         89       75       78
# 9  Mukesh      M  02-09-1989    96       46         77       83       58
#
#    economics  history  civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
def Studmarks(sql):
    que=pd.read_sql_query(sql,con)
    que

# %%
que=Studmarks('select * from student_marks')
que

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['math'])
# Out:
# (array([1., 0., 1., 0., 5., 0., 0., 2., 0., 1.]),
#  array([25. , 32.1, 39.2, 46.3, 53.4, 60.5, 67.6, 74.7, 81.8, 88.9, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(df['english'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f97cbc3e08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f97cbcadc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f97cbc33c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f97cbcdd48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f97cbcde48>],
#  'means': []}

# %%
plt.boxplot(df['history'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f97cc33bc8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f97cc37b88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f97cc33108>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f97cc3db08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f97cc3dc08>],
#  'means': []}

# %%
plt.violinplot(df['chemistry'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f97cc96ec8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f97cc56e48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f97cca1f48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f97cca1ec8>}

# %%
plt.violinplot(df['civics'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f97cd14908>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f97cb71b48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f97cd1ba48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f97cd1bf88>}

# %%
x=df['physics']
y=df['math']
plt.scatter(x,y)

# %%
ax=sns.stripplot(x='physics',y='chemistry',data=df)
ax.set(xlabel='Physics_marks',ylabel='Chemistry_marks')
plt.title('These two subject marks')
plt.show()

# %%
sns.set_style('dark')
sns.stripplot('history','civics',data=df)

# %%
sns.set_style('whitegrid')
sns.stripplot('english','biology',data=df)

# %%
sns.set_style('darkgrid')
sns.stripplot('history','economics',data=df)

# %%
sns.violinplot(x='english',y='biology',data=df)

# %%
sns.violinplot(x='history',data=df)

# %%
sns.violinplot('physics',data=df)

# %%
sns.violinplot(y='civics',data=df)

# %%
sns.violinplot('biology',data=df)

# %%
sns.swarmplot('math','biology',data=df)

# %%
sns.set(style='whitegrid')
sns.swarmplot('economics','history',data=df)

# %%
sns.swarmplot('physics','math',data=df)

# %%
sns.countplot(df['physics'])

# %%
sns.countplot(df['math'])

# %%
sns.catplot(x='math',y='biology',hue='gender',data=df)

# %%
sns.catplot(x='english',y='biology',hue='gender',data=df)

# %%
sns.set_style('darkgrid')
sns.catplot(x='physics',y='english',hue='gender',data=df,kind='violin')

# %%
sns.catplot(x='economics',y='civics',data=df,kind='bar')

# %%
sns.catplot('economics','history',hue='gender',data=df,kind='bar')

# %%
sns.catplot('english','economics',data=df,kind='point')

# %%
sns.catplot('math','english',hue='gender',data=df,kind='point')

# %%
sns.catplot(x='english',y='biology',col='gender',data=df,kind='bar')

# %%
sns.distplot(df['math'],bins=10)

# %%
sns.distplot(df['physics'],bins=20,kde=False)

# %%
sns.distplot(df['biology'],bins=10,rug=True)

# %%
sns.distplot(df['economics'],color='y')

# %%
sns.distplot(df['chemistry'],color='g')

# %%
sns.distplot(df['history'],color='r')

# %%
sns.distplot(df['english'],color='b')

# %%
sns.jointplot('math','physics',data=df,kind='kde')

# %%
sns.jointplot('english','biology',data=df,kind='hex')

# %%
sns.pairplot(df)

# %%
df=pd.DataFrame(np.random.rand(10,5),columns=['math','physics','biology','economics','civics'])
df.plot.bar()

# %%
df=pd.DataFrame(np.random.rand(10,4),columns=['chemistry','english','history','civics'])
df.plot.bar(stacked=True)

# %%
df=pd.DataFrame(np.random.rand(10,4),columns=['chemistry','english','history','civics'])
df.plot.barh(stacked=True)

# %%
df.shape
# Out:
# (10, 11)

# %%
df.dtypes
# Out:
# name         object
# gender       object
# dob          object
# math          int64
# physics       int64
# chemistry     int64
# english       int64
# biology       int64
# economics     int64
# history       int64
# civics        int64
# dtype: object

# %%
df.isnull()
# Out:
#     name  gender    dob   math  physics  chemistry  english  biology  \
# 0  False   False  False  False    False      False    False    False
# 1  False   False  False  False    False      False    False    False
# 2  False   False  False  False    False      False    False    False
# 3  False   False  False  False    False      False    False    False
# 4  False   False  False  False    False      False    False    False
# 5  False   False  False  False    False      False    False    False
# 6  False   False  False  False    False      False    False    False
# 7  False   False  False  False    False      False    False    False
# 8  False   False  False  False    False      False    False    False
# 9  False   False  False  False    False      False    False    False
#
#    economics  history  civics
# 0      False    False   False
# 1      False    False   False
# 2      False    False   False
# 3      False    False   False
# 4      False    False   False
# ...

# %%
df.describe()
# Out:
#             math    physics  chemistry    english    biology  economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          history   civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
df.corr()
# Out:
#                math   physics  chemistry   english   biology  economics  \
# math       1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# english   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# history   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             history    civics
# math      -0.320846 -0.274629
# physics    0.334082 -0.643266
# chemistry -0.482710  0.210908
# english   -0.038775  0.186705
# biology   -0.456131 -0.330060
# economics -0.164953  0.043905
# history    1.000000 -0.048686
# civics    -0.048686  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# As given dataset is saying perform all EDA.
# -  Firstly i have take the data from sql
# - I have shown almost all the EDA through this dataset.
# - I have also performed data cleaning.
